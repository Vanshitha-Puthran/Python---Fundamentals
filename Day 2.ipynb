# %%
Undersatnding the variablee in python

# %%
a=2
b=3
c=a+b
print(c)
# Out:
# 5

# %%
Rules for declaring the variables in python:
Rule 1: No namespace while declaring the variable

# %%
value 1=4
print(name 1)
# Out:
#   Cell In[8], line 1
#     value 1=4
#           ^
# SyntaxError: invalid syntax

# %%
value1=4
print(value1)
# Out:
# 4

# %%
Rule 2: A variable name should not start with a number

# %%
1value=6
print(1value)
# Out:
#   Cell In[9], line 1
#     1value=6
#     ^
# SyntaxError: invalid decimal literal

# %%
value2=67
print(value2)
# Out:
# 67

# %%
Rule 3:A variable name should not contain any special characters @ # $ % ! & *

# %%
value@=899
print(value@)
# Out:
#   Cell In[13], line 2
#     print(value@)
#                 ^
# SyntaxError: invalid syntax

# %%
Introduction To datatypes in python
1. string -- str
2. number -- integer(int) & float
3. list
4. tuple
5. dictionary -- dict

# %%
String

# %%
Fruit="Apple"
print(Fruit)
# Out:
# Apple

# %%
type(value2)
# Out:
# int

# %%
type(Fruit)
# Out:
# str

# %%
fullname="narashima kotian"
print(fullname.title())
# Out:
# Narashima Kotian

# %%
fullname="narashima kotian"
print(fullname.upper())
# Out:
# NARASHIMA KOTIAN

# %%
fullname="NARASHIMA KOTIAN"
print(fullname.lower())
# Out:
# narashima kotian
